# %% [markdown]
# ## Evaluation of showers submitted to the Fast Calorimeter Challenge 2022

# %% [markdown]
# This is an interactive version of the file ```evaluate.py```. It can also be run directly using:
#
# ```
# python evaluate.py -i INPUT_FILE -r REFERENCE_FILE -m MODE -d DATASET --output_dir OUTPUT_DIR --source_dir SOURCE_DIR
# ```
#
# where the arguments are:
#
# - ```INPUT_FILE``` is the .hdf5 file that contains the showers to be evaluated.
#
# - ```REFERENCE_FILE``` is either the .hdf5 file that contains the showers the input is compared to, or the .pkl file that is created when the code is run for the first time. The latter contains all relevant high-level features and using it results in a faster runtime.
#
# - ```MODE``` is one of [all, avg, avg-E, hist, hist-p, hist-chi], and defaults to 'all'. 'avg' plots the average shower of all provided events; 'avg-E' plots the average shower in smaller energy ranges; 'hist' plots histograms of high-level features and saves the separation power, a measure of difference between the histogram of the provided file and the histogram of a reference in SOURCE_DIR, into a file; 'hist-p' only plots the histograms; 'hist-chi' only saves the separation power; and 'all' does all of the above.
#
# - ```DATASET``` is the name of the dataset that should be evaluated. Must be one of [1-photons, 1-pions, 2, 3].
#
# - ```OUTPUT_DIR``` is the folder in which the plots and other files will be stored. It defaults to 'evaluation_results/'.
#
# - ```SOURCE_DIR``` is the folder in which the reference .pkl will be stored. In the future, it will also be where the .hdf5 files for the classifier are saved

# %%
import os
import evaluate
import argparse
import h5py
import numpy as np

import HighLevelFeatures as HLF

# %%
# specify to your needs:
big=False

INPUT_FILE = '/beegfs/desy/user/kaechben/calochallenge/new_post.hdf5'.format("big" if big else "middle") # REPLACE THIS WITH YOUR GENERATED EVENTS
REFERENCE_FILE = '/beegfs/desy/user/kaechben/calochallenge/dataset_{}.hdf5'.format("3_3" if big else "2_2") # These are the GEANT evaluation events that are provided on zenodo
#REFERENCE_FILE = 'source/dataset_2_2.pkl' # This is computed in the first run of the notebook. It can be used instead of the .hdf5 to save time in subsequent runs.
MODE = 'all' # not really needed here because the nb is interactive
DATASET = '3' if big else "2"
OUTPUT_DIR = 'evaluation_results_{}/'.format("big" if big else "middle")
SOURCE_DIR = 'source/'

# %%
# emulating the argument parser of evaluate.py
parser_replacement = {
    'input_file': INPUT_FILE, 'reference_file': REFERENCE_FILE, 'mode': MODE, 'dataset': DATASET, 
    'output_dir': OUTPUT_DIR, 'source_dir': SOURCE_DIR,"x_scale":"log","min_energy":"0.0001" }
args = argparse.Namespace(**parser_replacement)

# %%
# reading in source file
source_file = h5py.File(args.input_file, 'r')

# checking if it has correct shape
evaluate.check_file(source_file, args)

# preparing output directory
if not os.path.isdir(args.output_dir):
    os.makedirs(args.output_dir)

# preparing source directory
if not os.path.isdir(args.source_dir):
    os.makedirs(args.source_dir)

# extracting showers and energies from source file
shower, energy = evaluate.extract_shower_and_energy(source_file, args,)

# creating helper class for high-level features
particle = {'1-photons': 'photon', '1-pions': 'pion',
            '2': 'electron', '3': 'electron'}[args.dataset]
hlf = HLF.HighLevelFeatures(particle, filename='binning_dataset_{}.xml'.format(args.dataset.replace('-', '_')))
# Out:
# Checking if provided file has the correct form ...
# Found 100000 events in the file.
# Checking if provided file has the correct form: DONE
#
# Extracting showers from Namespace(input_file='/beegfs/desy/user/kaechben/calochallenge/new_post.hdf5', reference_file='/beegfs/desy/user/kaechben/calochallenge/dataset_2_2.hdf5', mode='all', dataset='2', output_dir='evaluation_results_middle/', source_dir='source/', x_scale='log', min_energy='0.0001') file ...
# Extracting showers from Namespace(input_file='/beegfs/desy/user/kaechben/calochallenge/new_post.hdf5', reference_file='/beegfs/desy/user/kaechben/calochallenge/dataset_2_2.hdf5', mode='all', dataset='2', output_dir='evaluation_results_middle/', source_dir='source/', x_scale='log', min_energy='0.0001') file: DONE.

# %%
# reading in reference
if os.path.splitext(args.reference_file)[1] == '.hdf5':
    with h5py.File(args.reference_file, "r") as reference_file:
        print("using .hdf5 reference")
        
        evaluate.check_file(reference_file, args, )#which='reference'
        reference_hlf = HLF.HighLevelFeatures(particle, filename='binning_dataset_{}.xml'.format(
            args.dataset.replace('-', '_')))
        reference_shower, reference_energy = evaluate.extract_shower_and_energy(reference_file, args)#, which='reference'
        reference_hlf.Einc = reference_energy
        evaluate.save_reference(reference_hlf, args.reference_file)
elif os.path.splitext(args.reference_file)[1] == '.pkl':
    print("using .pkl file for reference")
    reference_hlf = evaluate.load_reference(args.reference_file)
else:
    raise ValueError("reference_file must be .hdf5 or .pkl!")
# Out:
# using .hdf5 reference
# Checking if provided file has the correct form ...
# Found 100000 events in the file.
# Checking if provided file has the correct form: DONE
#
# Extracting showers from Namespace(input_file='/beegfs/desy/user/kaechben/calochallenge/new_post.hdf5', reference_file='/beegfs/desy/user/kaechben/calochallenge/dataset_2_2.hdf5', mode='all', dataset='2', output_dir='evaluation_results_middle/', source_dir='source/', x_scale='log', min_energy='0.0001') file ...
# Extracting showers from Namespace(input_file='/beegfs/desy/user/kaechben/calochallenge/new_post.hdf5', reference_file='/beegfs/desy/user/kaechben/calochallenge/dataset_2_2.hdf5', mode='all', dataset='2', output_dir='evaluation_results_middle/', source_dir='source/', x_scale='log', min_energy='0.0001') file: DONE.
#
# Saving file with high-level features.
# Saving file with high-level features DONE.

# %% [markdown]
# ### The cells below correspond to different evaluation MODEs and can be run independent of each other.

# %%
# evaluation mode 'avg': average of given showers
print("Plotting average shower...")
_ = hlf.DrawAverageShower(shower, filename=os.path.join(args.output_dir, 
                                                        'average_shower_dataset_{}.png'.format(args.dataset)),
                                  title="Shower average")
if hasattr(reference_hlf, 'avg_shower'):
    pass
else:
    reference_hlf.avg_shower = reference_shower.mean(axis=0, keepdims=True)
    evaluate.save_reference(reference_hlf, args.reference_file)
_ = hlf.DrawAverageShower(reference_hlf.avg_shower, 
                          filename=os.path.join(args.output_dir, 'reference_average_shower_dataset_{}.png'.format(
                                          args.dataset)),
                          title="Shower average reference dataset")
print("Plotting average shower: DONE.\n")
# Out:
# Plotting average shower...
# Saving file with high-level features.
# Saving file with high-level features DONE.
# Plotting average shower: DONE.

# %%
# evaluation mode 'avg-E': average showers at different energy ranges
print("Plotting average showers for different energies ...")
if '1' in args.dataset:
    target_energies = 2**np.linspace(8, 23, 16)
    plot_title = ['shower average at E = {} MeV'.format(int(en)) for en in target_energies]
else:
    target_energies = 10**np.linspace(3, 6, 4)
    plot_title = []
    for i in range(3, 7):
        plot_title.append('shower average for E in [{}, {}] MeV'.format(10**i, 10**(i+1)))
for i in range(len(target_energies)-1):
    filename = 'average_shower_dataset_{}_E_{}.png'.format(args.dataset,
                                                                   target_energies[i])
    which_showers = ((energy >= target_energies[i]) & (energy < target_energies[i+1])).squeeze()
    _ = hlf.DrawAverageShower(shower[which_showers],
                              filename=os.path.join(args.output_dir, filename),
                              title=plot_title[i])
    if hasattr(reference_hlf, 'avg_shower_E'):
        pass
    else:
        reference_hlf.avg_shower_E = {}
    if target_energies[i] in reference_hlf.avg_shower_E:
        pass
    else:
        which_showers = ((reference_hlf.Einc >= target_energies[i]) & (reference_hlf.Einc < target_energies[i+1])).squeeze()
        reference_hlf.avg_shower_E[target_energies[i]] = reference_shower[which_showers].mean(axis=0, keepdims=True)
        evaluate.save_reference(reference_hlf, args.reference_file)

        _ = hlf.DrawAverageShower(reference_hlf.avg_shower_E[target_energies[i]],
                                  filename=os.path.join(args.output_dir, 'reference_'+filename),
                                  title='reference '+plot_title[i])

print("Plotting average shower for different energies: DONE.\n")
# Out:
# Plotting average showers for different energies ...
# Saving file with high-level features.
# Saving file with high-level features DONE.
# Saving file with high-level features.
# Saving file with high-level features DONE.
# Saving file with high-level features.
# Saving file with high-level features DONE.
# Plotting average shower for different energies: DONE.

# %%
parser_replacement = {
    'input_file': INPUT_FILE, 'reference_file': REFERENCE_FILE, 'mode': MODE, 'dataset': DATASET, 
    'output_dir': OUTPUT_DIR, 'source_dir': SOURCE_DIR,"x_scale":"log","min_energy":0.0001 }
args = argparse.Namespace(**parser_replacement)

# %%
# evaluation mode 'hist': plotting histograms of high-level features and printing/saving the sepration power
# (equivalent to running hist-p for plotting and hist-chi for the separation power)
print("Calculating high-level features for histograms ...")
hlf.CalculateFeatures(shower)
hlf.Einc = energy

print("Calculating high-level features for histograms: DONE.\n")
if reference_hlf.E_tot is None:
    reference_hlf.CalculateFeatures(reference_shower)
    evaluate.save_reference(reference_hlf, args.reference_file)
print("Calculating high-level features for histograms: DONE.\n")

with open(os.path.join(args.output_dir, 'histogram_chi2_{}.txt'.format(args.dataset)), 'w') as f:
    f.write('List of chi2 of the plotted histograms, see eq. 15 of 2009.03796 for its definition.\n')
print("Plotting histograms ...")
# Out:
# Calculating high-level features for histograms ...
# Calculating high-level features for histograms: DONE.
#
# Saving file with high-level features.
# Saving file with high-level features DONE.
# Calculating high-level features for histograms: DONE.
#
# Plotting histograms ...

# %%
evaluate.plot_histograms(hlf, reference_hlf, args)
print("Plotting histograms: DONE. \n")
# Out:
# Separation power of Etot / Einc histogram: 0.5424839951108125
# Separation power of E layer 0 histogram: 0.01325840839088282
# Separation power of E layer 1 histogram: 0.017534618177106956
# Separation power of E layer 2 histogram: 0.02825236590181181
# Separation power of E layer 3 histogram: 0.03106643423606008
# Separation power of E layer 4 histogram: 0.03380025981647787
# Separation power of E layer 5 histogram: 0.03750876366685573
# Separation power of E layer 6 histogram: 0.03828409971648744
# Separation power of E layer 7 histogram: 0.03721592516454678
# Separation power of E layer 8 histogram: 0.03732834761303856
# Separation power of E layer 9 histogram: 0.037858448748847306
# Separation power of E layer 10 histogram: 0.03561947506945447
# Separation power of E layer 11 histogram: 0.0332845822627142
# Separation power of E layer 12 histogram: 0.03257035792913883
# Separation power of E layer 13 histogram: 0.03176614888205079
# Separation power of E layer 14 histogram: 0.03131940172982638
# Separation power of E layer 15 histogram: 0.030619929450575744
# Separation power of E layer 16 histogram: 0.02964749396747767
# Separation power of E layer 17 histogram: 0.028607429112289966
# Separation power of E layer 18 histogram: 0.02802225874189991
# Separation power of E layer 19 histogram: 0.026786297771975748
# Separation power of E layer 20 histogram: 0.024723238588151914
# Separation power of E layer 21 histogram: 0.02252188427556058
# Separation power of E layer 22 histogram: 0.021967875343968584
# Separation power of E layer 23 histogram: 0.021643999910907687
# Separation power of E layer 24 histogram: 0.021014177136242415
# Separation power of E layer 25 histogram: 0.020269506208714733
# Separation power of E layer 26 histogram: 0.019729225118534425
# Separation power of E layer 27 histogram: 0.018896039277750992
# Separation power of E layer 28 histogram: 0.018095556674364868
# Separation power of E layer 29 histogram: 0.018193393352565736
# Separation power of E layer 30 histogram: 0.018456364490271767
# Separation power of E layer 31 histogram: 0.01806882202727336
# Separation power of E layer 32 histogram: 0.01684534340065122
# Separation power of E layer 33 histogram: 0.016319474936565232
# Separation power of E layer 34 histogram: 0.014297436042113067
# Separation power of E layer 35 histogram: 0.011576436865550453
# Separation power of E layer 36 histogram: 0.010451919905278155
# Separation power of E layer 37 histogram: 0.009023784029171053
# Separation power of E layer 38 histogram: 0.008520631843314582
# Separation power of E layer 39 histogram: 0.0071928766054658215
# Separation power of E layer 40 histogram: 0.00698199613660233
# Separation power of E layer 41 histogram: 0.006540526277341588
# Separation power of E layer 42 histogram: 0.006548604820869131
# Separation power of E layer 43 histogram: 0.006325422257389741
# Separation power of E layer 44 histogram: 0.010915071541693893
# Separation power of EC Eta layer 0 histogram: 0.003788033490163421
# Separation power of EC Eta layer 1 histogram: 0.005418796045692879
# Separation power of EC Eta layer 2 histogram: 0.010448908480828304
# Separation power of EC Eta layer 3 histogram: 0.01723753740988809
# Separation power of EC Eta layer 4 histogram: 0.021983739729955033
# Separation power of EC Eta layer 5 histogram: 0.024667670602134463
# Separation power of EC Eta layer 6 histogram: 0.024594864644626332
# Separation power of EC Eta layer 7 histogram: 0.0238197537198158
# Separation power of EC Eta layer 8 histogram: 0.023909917043100366
# Separation power of EC Eta layer 9 histogram: 0.021405254813918962
# Separation power of EC Eta layer 10 histogram: 0.02095522791450295
# Separation power of EC Eta layer 11 histogram: 0.01894653676565985
# Separation power of EC Eta layer 12 histogram: 0.017490407403848104
# Separation power of EC Eta layer 13 histogram: 0.015534049800040169
# Separation power of EC Eta layer 14 histogram: 0.015194283931756996
# Separation power of EC Eta layer 15 histogram: 0.013177405433718028
# Separation power of EC Eta layer 16 histogram: 0.011890408957250886
# Separation power of EC Eta layer 17 histogram: 0.010800309818117006
# Separation power of EC Eta layer 18 histogram: 0.008853452700421937
# Separation power of EC Eta layer 19 histogram: 0.008137104597976022
# Separation power of EC Eta layer 20 histogram: 0.006954369854632734
# Separation power of EC Eta layer 21 histogram: 0.0050001648560297676
# Separation power of EC Eta layer 22 histogram: 0.0044712008254525325
# Separation power of EC Eta layer 23 histogram: 0.004106974690776116
# Separation power of EC Eta layer 24 histogram: 0.003519625144481887
# Separation power of EC Eta layer 25 histogram: 0.0031877844306525383
# Separation power of EC Eta layer 26 histogram: 0.002835434966692042
# Separation power of EC Eta layer 27 histogram: 0.002242333700865611
# Separation power of EC Eta layer 28 histogram: 0.0015912865723634946
# Separation power of EC Eta layer 29 histogram: 0.001364165646395713
# Separation power of EC Eta layer 30 histogram: 0.0014361365666616104
# Separation power of EC Eta layer 31 histogram: 0.001460884530203655
# Separation power of EC Eta layer 32 histogram: 0.0010543965383799576
# Separation power of EC Eta layer 33 histogram: 0.0007407106825607461
# Separation power of EC Eta layer 34 histogram: 0.0008360801633227174
# Separation power of EC Eta layer 35 histogram: 0.0008342672965496466
# Separation power of EC Eta layer 36 histogram: 0.0007882452657344736
# Separation power of EC Eta layer 37 histogram: 0.0007192547317907372
# Separation power of EC Eta layer 38 histogram: 0.0007498969465184606
# Separation power of EC Eta layer 39 histogram: 0.0007454250389026369
# Separation power of EC Eta layer 40 histogram: 0.0007302488089013329
# Separation power of EC Eta layer 41 histogram: 0.0006734093924320608
# Separation power of EC Eta layer 42 histogram: 0.0008911579127534144
# Separation power of EC Eta layer 43 histogram: 0.001126202691302193
# Separation power of EC Eta layer 44 histogram: 0.0014144459953682562
# Separation power of EC Phi layer 0 histogram: 0.0035008667293450067
# Separation power of EC Phi layer 1 histogram: 0.005439605859815516
# Separation power of EC Phi layer 2 histogram: 0.01013520594386909
# Separation power of EC Phi layer 3 histogram: 0.017397907407024835
# Separation power of EC Phi layer 4 histogram: 0.02236022066493932
# Separation power of EC Phi layer 5 histogram: 0.024671111662592185
# Separation power of EC Phi layer 6 histogram: 0.025570771942153667
# Separation power of EC Phi layer 7 histogram: 0.02314890443454432
# Separation power of EC Phi layer 8 histogram: 0.023010919752635216
# Separation power of EC Phi layer 9 histogram: 0.021348158982660233
# Separation power of EC Phi layer 10 histogram: 0.019305450459032435
# Separation power of EC Phi layer 11 histogram: 0.018373620458859017
# Separation power of EC Phi layer 12 histogram: 0.01672017089078829
# Separation power of EC Phi layer 13 histogram: 0.015692332478514613
# Separation power of EC Phi layer 14 histogram: 0.014259662984765293
# Separation power of EC Phi layer 15 histogram: 0.012896813977196227
# Separation power of EC Phi layer 16 histogram: 0.012629241010565312
# Separation power of EC Phi layer 17 histogram: 0.010965405202870919
# Separation power of EC Phi layer 18 histogram: 0.0091493566930525
# Separation power of EC Phi layer 19 histogram: 0.007947895911785944
# Separation power of EC Phi layer 20 histogram: 0.0068834342332808945
# Separation power of EC Phi layer 21 histogram: 0.005177391325747619
# Separation power of EC Phi layer 22 histogram: 0.004200742695536871
# Separation power of EC Phi layer 23 histogram: 0.004313528873050018
# Separation power of EC Phi layer 24 histogram: 0.003241295430469036
# Separation power of EC Phi layer 25 histogram: 0.0029341959201405836
# Separation power of EC Phi layer 26 histogram: 0.0027996467296914733
# Separation power of EC Phi layer 27 histogram: 0.002275393889568481
# Separation power of EC Phi layer 28 histogram: 0.0017305694907811247
# Separation power of EC Phi layer 29 histogram: 0.0014237915985413723
# Separation power of EC Phi layer 30 histogram: 0.0015002256086660533
# Separation power of EC Phi layer 31 histogram: 0.0012465103310010683
# Separation power of EC Phi layer 32 histogram: 0.0009031734614310888
# Separation power of EC Phi layer 33 histogram: 0.0006327520751387887
# Separation power of EC Phi layer 34 histogram: 0.0006379534785047812
# Separation power of EC Phi layer 35 histogram: 0.0006483737987169564
# Separation power of EC Phi layer 36 histogram: 0.0007635693681000333
# Separation power of EC Phi layer 37 histogram: 0.0006528778500907006
# Separation power of EC Phi layer 38 histogram: 0.0009093797121438971
# Separation power of EC Phi layer 39 histogram: 0.0009125135281976276
# Separation power of EC Phi layer 40 histogram: 0.0007422896111308051
# Separation power of EC Phi layer 41 histogram: 0.0006853920874984138
# Separation power of EC Phi layer 42 histogram: 0.0008867223340237167
# Separation power of EC Phi layer 43 histogram: 0.0011004437738835154
# Separation power of EC Phi layer 44 histogram: 0.0012702162083569717
# Separation power of Width Eta layer 0 histogram: 0.00601882849358432
# Separation power of Width Eta layer 1 histogram: 0.004954025852170447
# Separation power of Width Eta layer 2 histogram: 0.011074715559916064
# Separation power of Width Eta layer 3 histogram: 0.017329677590373797
# Separation power of Width Eta layer 4 histogram: 0.022602175527226737
# Separation power of Width Eta layer 5 histogram: 0.02980124855184544
# Separation power of Width Eta layer 6 histogram: 0.032033204953509004
# Separation power of Width Eta layer 7 histogram: 0.03192039023393017
# Separation power of Width Eta layer 8 histogram: 0.03712235648666262
# Separation power of Width Eta layer 9 histogram: 0.04193501654490978
# Separation power of Width Eta layer 10 histogram: 0.04306733378176461
# Separation power of Width Eta layer 11 histogram: 0.039924856046729185
# Separation power of Width Eta layer 12 histogram: 0.037946570939024676
# Separation power of Width Eta layer 13 histogram: 0.03421867436607585
# Separation power of Width Eta layer 14 histogram: 0.03176939707391665
# Separation power of Width Eta layer 15 histogram: 0.026790332699706546
# Separation power of Width Eta layer 16 histogram: 0.024556496938310534
# Separation power of Width Eta layer 17 histogram: 0.020524501464298413
# Separation power of Width Eta layer 18 histogram: 0.015510704036952155
# Separation power of Width Eta layer 19 histogram: 0.01198868751964484
# Separation power of Width Eta layer 20 histogram: 0.009581166243024974
# Separation power of Width Eta layer 21 histogram: 0.007646590045240076
# Separation power of Width Eta layer 22 histogram: 0.006869052194136533
# Separation power of Width Eta layer 23 histogram: 0.005872840829504678
# Separation power of Width Eta layer 24 histogram: 0.005565490663026217
# Separation power of Width Eta layer 25 histogram: 0.004458625744047812
# Separation power of Width Eta layer 26 histogram: 0.004238215468367224
# Separation power of Width Eta layer 27 histogram: 0.003192132991880328
# Separation power of Width Eta layer 28 histogram: 0.0030255325237257043
# Separation power of Width Eta layer 29 histogram: 0.002508011707248625
# Separation power of Width Eta layer 30 histogram: 0.0021774624792808496
# Separation power of Width Eta layer 31 histogram: 0.001948591538288377
# Separation power of Width Eta layer 32 histogram: 0.0018981830700645784
# Separation power of Width Eta layer 33 histogram: 0.001288353387414692
# Separation power of Width Eta layer 34 histogram: 0.0011079230358534832
# Separation power of Width Eta layer 35 histogram: 0.001313066302889082
# Separation power of Width Eta layer 36 histogram: 0.0016349090042158205
# Separation power of Width Eta layer 37 histogram: 0.0013405339982067847
# Separation power of Width Eta layer 38 histogram: 0.0015768764241757952
# Separation power of Width Eta layer 39 histogram: 0.0013410460742835303
# Separation power of Width Eta layer 40 histogram: 0.0019384311386090227
# Separation power of Width Eta layer 41 histogram: 0.002216784195044132
# Separation power of Width Eta layer 42 histogram: 0.003358408125017353
# Separation power of Width Eta layer 43 histogram: 0.004454431103724599
# Separation power of Width Eta layer 44 histogram: 0.003420391098766964
# Separation power of Width Phi layer 0 histogram: 0.004702472832395957
# Separation power of Width Phi layer 1 histogram: 0.004819091153186768
# Separation power of Width Phi layer 2 histogram: 0.011747361582039165
# Separation power of Width Phi layer 3 histogram: 0.017726901777812998
# Separation power of Width Phi layer 4 histogram: 0.02468855251213109
# Separation power of Width Phi layer 5 histogram: 0.03089595853121569
# Separation power of Width Phi layer 6 histogram: 0.03489213427268303
# Separation power of Width Phi layer 7 histogram: 0.035521609303190406
# Separation power of Width Phi layer 8 histogram: 0.037179057847187176
# Separation power of Width Phi layer 9 histogram: 0.04379557423390347
# Separation power of Width Phi layer 10 histogram: 0.04391177605766338
# Separation power of Width Phi layer 11 histogram: 0.041039471936798536
# Separation power of Width Phi layer 12 histogram: 0.03769440917405211
# Separation power of Width Phi layer 13 histogram: 0.03343538002623025
# Separation power of Width Phi layer 14 histogram: 0.03157817582478653
# Separation power of Width Phi layer 15 histogram: 0.028117469672313943
# Separation power of Width Phi layer 16 histogram: 0.023669397290968123
# Separation power of Width Phi layer 17 histogram: 0.01969190563692644
# Separation power of Width Phi layer 18 histogram: 0.014860600064809281
# Separation power of Width Phi layer 19 histogram: 0.012139892522330402
# Separation power of Width Phi layer 20 histogram: 0.009177105321298642
# Separation power of Width Phi layer 21 histogram: 0.007725412776865686
# Separation power of Width Phi layer 22 histogram: 0.006262352133476944
# Separation power of Width Phi layer 23 histogram: 0.004974443502736178
# Separation power of Width Phi layer 24 histogram: 0.004802801489799599
# Separation power of Width Phi layer 25 histogram: 0.003928983974975164
# Separation power of Width Phi layer 26 histogram: 0.0035725548313844746
# Separation power of Width Phi layer 27 histogram: 0.00308996824982403
# Separation power of Width Phi layer 28 histogram: 0.002579110934629706
# Separation power of Width Phi layer 29 histogram: 0.0022896161498038594
# Separation power of Width Phi layer 30 histogram: 0.0019427022959064937
# Separation power of Width Phi layer 31 histogram: 0.0013256488043213103
# Separation power of Width Phi layer 32 histogram: 0.0013946937871636002
# Separation power of Width Phi layer 33 histogram: 0.0012711778696595677
# Separation power of Width Phi layer 34 histogram: 0.001380446502025009
# Separation power of Width Phi layer 35 histogram: 0.0015262131526074514
# Separation power of Width Phi layer 36 histogram: 0.0014249536038900578
# Separation power of Width Phi layer 37 histogram: 0.0013532643687473997
# Separation power of Width Phi layer 38 histogram: 0.0015872723730844967
# Separation power of Width Phi layer 39 histogram: 0.0018447365350145628
# Separation power of Width Phi layer 40 histogram: 0.0020744906246760895
# Separation power of Width Phi layer 41 histogram: 0.002727049492094296
# Separation power of Width Phi layer 42 histogram: 0.003546527238966624
# Separation power of Width Phi layer 43 histogram: 0.004302161543448698
# Separation power of Width Phi layer 44 histogram: 0.0033646688839206974
# Plotting histograms: DONE.

# %%
source_file.close()
h5py.File(args.reference_file).close()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[11], line 2
#       1 source_file.close()
# ----> 2 h5py.File(args.reference_file).close()
#
# File /beegfs/desy/user/kaechben/.conda/envs/torch_wandb/lib/python3.10/site-packages/h5py/_hl/files.py:567, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     558     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     559                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     560                      alignment_threshold=alignment_threshold,
#     561                      alignment_interval=alignment_interval,
#     562                      meta_block_size=meta_block_size,
#     563                      **kwds)
#     564     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     565                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     566                      fs_page_size=fs_page_size)
# --> 567     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     569 if isinstance(libver, tuple):
#     570     self._libver = libver
#
# File /beegfs/desy/user/kaechben/.conda/envs/torch_wandb/lib/python3.10/site-packages/h5py/_hl/files.py:231, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     229     if swmr and swmr_support:
#     230         flags |= h5f.ACC_SWMR_READ
# --> 231     fid = h5f.open(name, flags, fapl=fapl)
#     232 elif mode == 'r+':
#     233     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:106, in h5py.h5f.open()
#
# OSError: Unable to open file (file signature not found)

# %%
reference_file.close()
